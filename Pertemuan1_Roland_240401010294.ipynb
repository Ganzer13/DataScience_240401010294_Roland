# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganzer13/DataScience_240401010294_Roland/blob/main/Pertemuan1_Roland_240401010294.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama  : Roland Albertian Sehapikang</br>
# Kelas : IF403</br>
# NIM   : 240401010294

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "Mahasiswa Informatika" # String
angkatan = 2024 # Integer
ipk = 3.75 # Float
aktif = True # Boolean
print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Mahasiswa Informatika
# Angkatan: 2024
# IPK : 3.75
# Aktif : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
 print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
 """Fungsi untuk menampilkan perkenalan mahasiswa."""
 return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."
hasil = perkenalan("Budi Santoso", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Budi Santoso dari Informatika, angkatan 2024.

# %% [markdown]
# **1. Apa yang dipelajari?**
# * Dasar Sintaksis Python: Memahami cara menampilkan teks ke layar menggunakan fungsi print()
# * Variabel dan Tipe Data: Cara mendeklarasikan dan menggunakan tipe data fundamental seperti String (nama), Integer (angkatan), Float (ipk), dan Boolean (aktif), serta penggabungannya menggunakan f-string.
# * Struktur Data & Iterasi: Membuat kumpulan data terurut menggunakan List (tools) dan mengekstrak isinya satu per satu menggunakan perulangan for bersama fungsi enumerate()
# * Fungsi (Function): Membuat blok kode yang dapat digunakan kembali (reusable) menggunakan kata kunci def, lengkap dengan parameter, docstring, dan pengembalian nilai (return).
#
# **2. Temuan Utama**
# * Python memiliki sintaksis yang sangat bersih dan mudah dibaca (inklusif untuk pemula) karena tidak memerlukan tanda titik koma (;) di akhir baris atau deklarasi tipe data secara eksplisit.
# * Notebook ini berhasil memperkenalkan ekosistem dasar yang wajib dikuasai sebelum masuk ke analisis data, yaitu pemahaman logika pemrograman dan pengenalan tools penunjang (Python, Google Colab, Jupyter Notebook, GitHub).
#
# **3. Keterbatasan atau Pertanyaan yang muncul**
# * Keterbatasan Kode: Kode ini masih bersifat statis dan belum melakukan analisis data nyata, manipulasi dataset, ataupun visualisasi grafik yang menjadi inti dari Data Science.
# * Pertanyaan yang Muncul:
#   1. Bagaimana cara mengimpor library eksternal khusus Data Science (seperti NumPy atau Pandas) ke dalam struktur notebook seperti ini?
#   2. Bagaimana cara menangani input data yang dinamis atau membaca file eksternal (misal: format .csv atau .json) bukan hanya menulis variabel secara manual di dalam sel?
